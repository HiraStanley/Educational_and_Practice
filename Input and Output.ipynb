# %%
import pandas as pd

# %%
url = "https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv"
babynames = pd.read_csv(url)
babynames.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %% [markdown]
# # Export to CSV

# %%
babynames.to_csv("test_export.csv", index=False)

# %%
babynames.to_csv("test_export.csv", index=False, columns=["Year of Birth", "Child's First Name", "Count"])

# %% [markdown]
# # Read in Excel File

# %%
logins = pd.read_excel("Logins Raw Data.xlsx")
logins.head()
# Out:
#        month  subscribers_logins  subscribers  login_rate
# 0 2020-01-01               14728        82407    0.178723
# 1 2020-02-01               14184        82062    0.172845
# 2 2020-03-01               14048        81291    0.172811
# 3 2020-04-01               13047        80555    0.161964
# 4 2020-05-01               12955        79762    0.162421

# %%
multisheet = pd.read_excel("Migrations_Aug2023.xlsx", sheet_name="Migrated Reports")
multisheet.head()
# Out:
#                                    Email Subject  \
# 0  ALERT:Exception Report - Credit Card & eCheck
# 1               Customer Email BounceBack Report
# 2            Daily PHX-to-WD Export Recon Report
# 3                         DNC Disposition Report
# 4                           DUNS Manager Summary
#
#                                                  EGP  \
# 0       Production\Financial\Exception Report_v1.egp
# 1      Production\Monitoring\EmailBounce_Monthly.egp
# 2  Production\Monitoring\Daily PHX to WD Export R...
# 3      Production\Monitoring\EmailBounce_Monthly.egp
# 4            Production\Sales\DUNSManager_Report.egp
#
#                                        Source tables EGP migrated to SQL  \
# 0  EDWStaging.RECONCILIATION.reconcile_edw\nedwv2...                Done
# 1  ods.event.operational_sales\nBI_CAMPAIGN_PROD....                Done
# 2  IntraDay.EComm.financial_transaction\nIntraDay...                Done
# ...

# %%
multi = pd.read_excel("Migrations_Aug2023.xlsx", sheet_name=[0,1])

# %%
multi[0].head()
# Out:
#                                          Details  # Users that Need Report  \
# 0                        Cancels Campaign Report                         1
# 1                    CreditMonitor Sales Report                          4
# 2                    Subscription Billing Report                         4
# 3                     Web Orders Campaign Report                         3
# 4  Intra-Day D&B Small Business Telesales Report                        12
#
#                                            Frequency                  Status  \
# 0                                   Monthly - Day 28      Hira having issues
# 1                                           Daily x1      Hira having issues
# 2                                           Daily x1  Need underlying tables
# 3                                           Daily x1      Hira having issues
# 4  Daily, every 30 mins between 10am and 10.30 pm...  Need underlying tables
#
# ...

# %% [markdown]
# # Export to Excel

# %%
females = babynames[babynames["Gender"] == "FEMALE"]
males = babynames[babynames["Gender"] == "MALE"]

# %%
with pd.ExcelWriter("NYC Baby Data.xlsx") as excel_file:
    females.to_excel(excel_file, sheet_name="Females", index=False)
    males.to_excel(excel_file, sheet_name="Males", index=False, columns=["Year of Birth", "Child's First Name", "Rank"])
